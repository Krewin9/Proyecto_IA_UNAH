# %%
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import os

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# %%
from pathlib import Path

proyecto = Path.cwd().parent
print("Carpeta del proyecto:", proyecto)

print("\nContenido de la carpeta del proyecto:")
for p in proyecto.iterdir():
    print(p.name)
# Out:
# Carpeta del proyecto: c:\Users\User\Desktop\Proyecto_IA
#
# Contenido de la carpeta del proyecto:
# agente
# api
# dataset
# documentos
# logs
# modelo
# notebooks
# requerimientos.txt

# %%
DATASET_PATH = Path(r"c:\Users\User\Desktop\Proyecto_IA\dataset\accepted_2007_to_2018Q4.csv")

print("Ruta:", DATASET_PATH)
print("activo:", DATASET_PATH.exists())

df = pd.read_csv(DATASET_PATH, low_memory=False, nrows=5)
display(df)
# Out:
# Ruta: c:\Users\User\Desktop\Proyecto_IA\dataset\accepted_2007_to_2018Q4.csv
# activo: True
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.99       123.03     C        C4  ...                            NaN
# 1     11.99       820.28     C        C1  ...                            NaN
# 2     10.78       432.66     B        B4  ...                            NaN
# 3     14.85       829.90     C        C5  ...                            NaN
# 4     22.45       289.91     F        F1  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
# 1                          NaN                Cash                     N
# 2                          NaN                Cash                     N
# 3                          NaN                Cash                     N
# 4                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage  settlement_term
# 0               NaN                   NaN              NaN
# 1               NaN                   NaN              NaN
# 2               NaN                   NaN              NaN
# 3               NaN                   NaN              NaN
# 4               NaN                   NaN              NaN
#
# [5 rows x 151 columns]

# %%
df = pd.read_csv(DATASET_PATH, low_memory=False)
print(df.shape)
# Out:
# (2260701, 151)

# %%
print("Filas y columnas:")
print(df.shape)

print("\n" + "="*60)


df.info()
# Out:
# Filas y columnas:
# (2260701, 151)
#
# ============================================================
# <class 'pandas.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), str(38)
# memory usage: 2.5 GB

# %%
df.describe(include="all").T
# Out:
#                            count   unique       top   freq          mean  \
# id                       2260701  2260701  68407277      1           NaN
# member_id                    0.0      NaN       NaN    NaN           NaN
# loan_amnt              2260668.0      NaN       NaN    NaN  15046.931228
# funded_amnt            2260668.0      NaN       NaN    NaN  15041.664057
# funded_amnt_inv        2260668.0      NaN       NaN    NaN  15023.437745
# ...                          ...      ...       ...    ...           ...
# settlement_status          34246        3    ACTIVE  14704           NaN
# settlement_date            34246       90  Jan-2019   1710           NaN
# settlement_amount        34246.0      NaN       NaN    NaN   5010.664267
# settlement_percentage    34246.0      NaN       NaN    NaN     47.780365
# settlement_term          34246.0      NaN       NaN    NaN     13.191322
#
#                                std    min     25%      50%        75%      max
# id                             NaN    NaN     NaN      NaN        NaN      NaN
# member_id                      NaN    NaN     NaN      NaN        NaN      NaN
# loan_amnt              9190.245488  500.0  8000.0  12900.0    20000.0  40000.0
# funded_amnt            9188.413022  500.0  8000.0  12875.0    20000.0  40000.0
# funded_amnt_inv        9192.331679    0.0  8000.0  12800.0    20000.0  40000.0
# ...                            ...    ...     ...      ...        ...      ...
# settlement_status              NaN    NaN     NaN      NaN        NaN      NaN
# settlement_date                NaN    NaN     NaN      NaN        NaN      NaN
# settlement_amount       3693.12259  44.21  2208.0  4146.11  6850.1725  33601.0
# settlement_percentage     7.311822    0.2    45.0     45.0       50.0   521.35
# settlement_term            8.15998    0.0     6.0     14.0       18.0    181.0
#
# [151 rows x 11 columns]

# %%
loan_status = df["loan_status"].value_counts()

print(loan_status)
# Out:
# loan_status
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: count, dtype: int64

# %%
loan_status_pct = (
    df["loan_status"]
    .value_counts(normalize=True)
    .mul(100)
    .round(2)
)

loan_status_pct
# Out:
# loan_status
# Fully Paid                                             47.63
# Current                                                38.85
# Charged Off                                            11.88
# Late (31-120 days)                                      0.95
# In Grace Period                                         0.37
# Late (16-30 days)                                       0.19
# Does not meet the credit policy. Status:Fully Paid      0.09
# Does not meet the credit policy. Status:Charged Off     0.03
# Default                                                 0.00
# Name: proportion, dtype: float64

# %%
grupo_prestamo = [
    "loan_amnt",
    "funded_amnt",
    "funded_amnt_inv",
    "term",
    "int_rate",
    "installment",
    "grade",
    "sub_grade",
    "purpose"
]

df[grupo_prestamo].head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0     3600.0       3600.0           3600.0   36 months     13.99       123.03
# 1    24700.0      24700.0          24700.0   36 months     11.99       820.28
# 2    20000.0      20000.0          20000.0   60 months     10.78       432.66
# 3    35000.0      35000.0          35000.0   60 months     14.85       829.90
# 4    10400.0      10400.0          10400.0   60 months     22.45       289.91
#
#   grade sub_grade             purpose
# 0     C        C4  debt_consolidation
# 1     C        C1      small_business
# 2     B        B4    home_improvement
# 3     C        C5  debt_consolidation
# 4     F        F1      major_purchase

# %%
df[grupo_prestamo].describe(include="all").T
# Out:
#                      count unique                 top     freq          mean  \
# loan_amnt        2260668.0    NaN                 NaN      NaN  15046.931228
# funded_amnt      2260668.0    NaN                 NaN      NaN  15041.664057
# funded_amnt_inv  2260668.0    NaN                 NaN      NaN  15023.437745
# term               2260668      2           36 months  1609754           NaN
# int_rate         2260668.0    NaN                 NaN      NaN     13.092829
# installment      2260668.0    NaN                 NaN      NaN    445.806823
# grade              2260668      7                   B   663557           NaN
# sub_grade          2260668     35                  C1   145903           NaN
# purpose            2260668     14  debt_consolidation  1277877           NaN
#
#                          std    min     25%      50%      75%      max
# loan_amnt        9190.245488  500.0  8000.0  12900.0  20000.0  40000.0
# funded_amnt      9188.413022  500.0  8000.0  12875.0  20000.0  40000.0
# funded_amnt_inv  9192.331679    0.0  8000.0  12800.0  20000.0  40000.0
# term                     NaN    NaN     NaN      NaN      NaN      NaN
# int_rate            4.832138   5.31    9.49    12.62    15.99    30.99
# installment       267.173535   4.93  251.65   377.99   593.32  1719.83
# grade                    NaN    NaN     NaN      NaN      NaN      NaN
# sub_grade                NaN    NaN     NaN      NaN      NaN      NaN
# purpose                  NaN    NaN     NaN      NaN      NaN      NaN

# %%
valores_nulos = (
    df.isnull()
      .mean()
      .mul(100)
      .round(2)
      .sort_values(ascending=False)
)

valores_nulos.head(40)
# Out:
# member_id                                     100.00
# orig_projected_additional_accrued_interest     99.62
# hardship_reason                                99.52
# hardship_payoff_balance_amount                 99.52
# hardship_last_payment_amount                   99.52
# payment_plan_start_date                        99.52
# hardship_type                                  99.52
# hardship_status                                99.52
# hardship_start_date                            99.52
# deferral_term                                  99.52
# hardship_amount                                99.52
# hardship_dpd                                   99.52
# hardship_loan_status                           99.52
# hardship_length                                99.52
# hardship_end_date                              99.52
# settlement_status                              98.49
# debt_settlement_flag_date                      98.49
# settlement_term                                98.49
# settlement_percentage                          98.49
# settlement_date                                98.49
# settlement_amount                              98.49
# sec_app_mths_since_last_major_derog            98.41
# sec_app_revol_util                             95.30
# sec_app_num_rev_accts                          95.22
# sec_app_earliest_cr_line                       95.22
# sec_app_mort_acc                               95.22
# sec_app_open_acc                               95.22
# revol_bal_joint                                95.22
# sec_app_fico_range_low                         95.22
# sec_app_open_act_il                            95.22
# sec_app_inq_last_6mths                         95.22
# sec_app_fico_range_high                        95.22
# sec_app_collections_12_mths_ex_med             95.22
# sec_app_chargeoff_within_12_mths               95.22
# verification_status_joint                      94.88
# annual_inc_joint                               94.66
# dti_joint                                      94.66
# desc                                           94.42
# mths_since_last_record                         84.11
# mths_since_recent_bc_dlq                       77.01
# dtype: float64

# %%
variables_importantes = [
    "loan_amnt",
    "term",
    "emp_length",
    "home_ownership",
    "annual_inc",
    "verification_status",
    "purpose",
    "dti",
    "fico_range_low",
    "fico_range_high",
    "delinq_2yrs",
    "inq_last_6mths",
    "open_acc",
    "total_acc",
    "pub_rec_bankruptcies"
]

df[variables_importantes].isnull().sum().sort_values(ascending=False)
# Out:
# emp_length              146940
# dti                       1744
# pub_rec_bankruptcies      1398
# inq_last_6mths              63
# delinq_2yrs                 62
# total_acc                   62
# open_acc                    62
# annual_inc                  37
# purpose                     33
# home_ownership              33
# term                        33
# loan_amnt                   33
# verification_status         33
# fico_range_high             33
# fico_range_low              33
# dtype: int64

# %%
columnas_candidatas = [

    "loan_amnt",
    "term",
    "purpose",
    "annual_inc",
    "verification_status",
    "emp_length",
    "home_ownership",
    "dti",
    "fico_range_low",
    "fico_range_high",
    "delinq_2yrs",
    "inq_last_6mths",
    "open_acc",
    "total_acc",
    "pub_rec",
    "pub_rec_bankruptcies",
    "mort_acc",
    "revol_bal",
    "revol_util",
    "collections_12_mths_ex_med",
    "acc_now_delinq",
    "tax_liens",
    "tot_coll_amt",
    "tot_cur_bal",
    "num_sats",
    
    "loan_status"
]

len(columnas_candidatas)
# Out:
# 26

# %%
df_reducido = df[columnas_candidatas].copy()

print("Dimensiones del DataFrame original:")
print(df.shape)
print("Dimensiones del DataFrame reducido:")
print(df_reducido.shape)
# Out:
# Dimensiones del DataFrame original:
# (2260701, 151)
# Dimensiones del DataFrame reducido:
# (2260701, 26)

# %%
df_reducido.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Data columns (total 26 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   loan_amnt                   float64
#  1   term                        str
#  2   purpose                     str
#  3   annual_inc                  float64
#  4   verification_status         str
#  5   emp_length                  str
#  6   home_ownership              str
#  7   dti                         float64
#  8   fico_range_low              float64
#  9   fico_range_high             float64
#  10  delinq_2yrs                 float64
#  11  inq_last_6mths              float64
#  12  open_acc                    float64
#  13  total_acc                   float64
#  14  pub_rec                     float64
#  15  pub_rec_bankruptcies        float64
#  16  mort_acc                    float64
#  17  revol_bal                   float64
#  18  revol_util                  float64
#  19  collections_12_mths_ex_med  float64
#  20  acc_now_delinq              float64
#  21  tax_liens                   float64
#  22  tot_coll_amt                float64
#  23  tot_cur_bal                 float64
#  24  num_sats                    float64
#  25  loan_status                 str
# dtypes: float64(20), str(6)
# memory usage: 448.4 MB

# %%
df_reducido.describe().T
# Out:
#                                 count           mean            std    min  \
# loan_amnt                   2260668.0   15046.931228    9190.245488  500.0
# annual_inc                  2260664.0   77992.428687  112696.199574    0.0
# dti                         2258957.0      18.824196      14.183329   -1.0
# fico_range_low              2260668.0     698.588205      33.010376  610.0
# fico_range_high             2260668.0     702.588400      33.011245  614.0
# delinq_2yrs                 2260639.0       0.306879       0.867230    0.0
# inq_last_6mths              2260638.0       0.576835       0.885963    0.0
# open_acc                    2260639.0      11.612402       5.640861    0.0
# total_acc                   2260639.0      24.162552      11.987528    1.0
# pub_rec                     2260639.0       0.197528       0.570515    0.0
# pub_rec_bankruptcies        2259303.0       0.128194       0.364613    0.0
# mort_acc                    2210638.0       1.555382       1.904981    0.0
# revol_bal                   2260668.0   16658.458078   22948.305028    0.0
# revol_util                  2258866.0      50.337696      24.713073    0.0
# collections_12_mths_ex_med  2260523.0       0.018146       0.150813    0.0
# acc_now_delinq              2260639.0       0.004148       0.069617    0.0
# tax_liens                   2260563.0       0.046771       0.377534    0.0
# tot_coll_amt                2190392.0     232.731739    8518.461819    0.0
# tot_cur_bal                 2190392.0  142492.195202  160692.640617    0.0
# num_sats                    2202078.0      11.628130       5.644027    0.0
#
#                                  25%       50%        75%          max
# loan_amnt                    8000.00  12900.00   20000.00      40000.0
# annual_inc                  46000.00  65000.00   93000.00  110000000.0
# dti                            11.89     17.84      24.49        999.0
# fico_range_low                675.00    690.00     715.00        845.0
# fico_range_high               679.00    694.00     719.00        850.0
# delinq_2yrs                     0.00      0.00       0.00         58.0
# inq_last_6mths                  0.00      0.00       1.00         33.0
# open_acc                        8.00     11.00      14.00        101.0
# total_acc                      15.00     22.00      31.00        176.0
# pub_rec                         0.00      0.00       0.00         86.0
# pub_rec_bankruptcies            0.00      0.00       0.00         12.0
# mort_acc                        0.00      1.00       3.00         94.0
# revol_bal                    5950.00  11324.00   20246.00    2904836.0
# revol_util                     31.50     50.30      69.40        892.3
# collections_12_mths_ex_med      0.00      0.00       0.00         20.0
# acc_now_delinq                  0.00      0.00       0.00         14.0
# tax_liens                       0.00      0.00       0.00         85.0
# tot_coll_amt                    0.00      0.00       0.00    9152545.0
# tot_cur_bal                 29092.00  79240.00  213204.00    9971659.0
# num_sats                        8.00     11.00      14.00        101.0

# %%
nulos = (
    df_reducido
    .isnull()
    .sum()
    .sort_values(ascending=False)
)

nulos
# Out:
# emp_length                    146940
# tot_coll_amt                   70309
# tot_cur_bal                    70309
# num_sats                       58623
# mort_acc                       50063
# revol_util                      1835
# dti                             1744
# pub_rec_bankruptcies            1398
# collections_12_mths_ex_med       178
# tax_liens                        138
# inq_last_6mths                    63
# delinq_2yrs                       62
# open_acc                          62
# total_acc                         62
# acc_now_delinq                    62
# pub_rec                           62
# annual_inc                        37
# loan_amnt                         33
# fico_range_high                   33
# fico_range_low                    33
# home_ownership                    33
# verification_status               33
# purpose                           33
# term                              33
# revol_bal                         33
# loan_status                       33
# dtype: int64

# %%
df_reducido["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: count, dtype: int64

# %%
porcentaje_nulos = (
    df_reducido
    .isnull()
    .mean() * 100
).sort_values(ascending=False)

porcentaje_nulos
# Out:
# emp_length                    6.499754
# tot_coll_amt                  3.110053
# tot_cur_bal                   3.110053
# num_sats                      2.593134
# mort_acc                      2.214490
# revol_util                    0.081170
# dti                           0.077144
# pub_rec_bankruptcies          0.061839
# collections_12_mths_ex_med    0.007874
# tax_liens                     0.006104
# inq_last_6mths                0.002787
# delinq_2yrs                   0.002743
# open_acc                      0.002743
# total_acc                     0.002743
# acc_now_delinq                0.002743
# pub_rec                       0.002743
# annual_inc                    0.001637
# loan_amnt                     0.001460
# fico_range_high               0.001460
# fico_range_low                0.001460
# home_ownership                0.001460
# verification_status           0.001460
# purpose                       0.001460
# term                          0.001460
# revol_bal                     0.001460
# loan_status                   0.001460
# dtype: float64

# %%
nivel_riesgo = {
    "Fully Paid": 0,
    "Late (16-30 days)": 1,
    "Late (31-120 days)": 1,
    "In Grace Period": 1,
    "Charged Off": 2
}

# %%
df_reducido["risk_level"] = df_reducido["loan_status"].map(nivel_riesgo)

df_reducido[["loan_status", "risk_level"]].head()
# Out:
#   loan_status  risk_level
# 0  Fully Paid         0.0
# 1  Fully Paid         0.0
# 2  Fully Paid         0.0
# 3     Current         NaN
# 4  Fully Paid         0.0

# %%
df_reducido[
    ["loan_status", "risk_level"]
].drop_duplicates().sort_values(
    by="risk_level",
    na_position="last"
)
# Out:
#                                                loan_status  risk_level
# 0                                               Fully Paid         0.0
# 66                                         In Grace Period         1.0
# 227                                     Late (31-120 days)         1.0
# 1250                                     Late (16-30 days)         1.0
# 13                                             Charged Off         2.0
# 3                                                  Current         NaN
# 33636                                              Default         NaN
# 421095                                                 NaN         NaN
# 1651666  Does not meet the credit policy. Status:Fully ...         NaN
# 1651667  Does not meet the credit policy. Status:Charge...         NaN

# %%
df_modelo = df_reducido.dropna(
    subset=["risk_level"]
).copy()

print("Registros antes del filtro:", len(df_reducido))
print("Registros después del filtro:", len(df_modelo))
# Out:
# Registros antes del filtro: 2260701
# Registros después del filtro: 1379562

# %%
df_modelo["risk_level"] = df_modelo["risk_level"].astype(int)

df_modelo["risk_level"].dtype
# Out:
# dtype('int64')

# %%
conteo_riesgo = (
    df_modelo["risk_level"]
    .value_counts()
    .sort_index()
)

porcentaje_riesgo = (
    df_modelo["risk_level"]
    .value_counts(normalize=True)
    .sort_index() * 100
)

distribucion_riesgo = pd.DataFrame({
    "cantidad": conteo_riesgo,
    "porcentaje": porcentaje_riesgo.round(2)
})

distribucion_riesgo.index = [
    "Riesgo bajo",
    "Riesgo medio",
    "Riesgo alto"
]

distribucion_riesgo
# Out:
#               cantidad  porcentaje
# Riesgo bajo    1076751       78.05
# Riesgo medio     34252        2.48
# Riesgo alto     268559       19.47

# %%
distribucion_riesgo["cantidad"].plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Distribución de los niveles de riesgo")
plt.xlabel("Nivel de riesgo")
plt.ylabel("Cantidad de préstamos")
plt.xticks(rotation=0)
plt.show()

# %%
X = df_modelo.drop(columns=["loan_status", "risk_level"])

y = df_modelo["risk_level"]

# %%
X.dtypes
# Out:
# loan_amnt                     float64
# term                              str
# purpose                           str
# annual_inc                    float64
# verification_status               str
# emp_length                        str
# home_ownership                    str
# dti                           float64
# fico_range_low                float64
# fico_range_high               float64
# delinq_2yrs                   float64
# inq_last_6mths                float64
# open_acc                      float64
# total_acc                     float64
# pub_rec                       float64
# pub_rec_bankruptcies          float64
# mort_acc                      float64
# revol_bal                     float64
# revol_util                    float64
# collections_12_mths_ex_med    float64
# acc_now_delinq                float64
# tax_liens                     float64
# tot_coll_amt                  float64
# tot_cur_bal                   float64
# num_sats                      float64
# dtype: object

# %%
variables_numericas = X.select_dtypes(
    include=["number"]
).columns.tolist()

variables_categoricas = X.select_dtypes(
    include=["object", "string"]
).columns.tolist()

# %%
print("Variables numéricas:", len(variables_numericas))

print("Variables categóricas:", len(variables_categoricas))
# Out:
# Variables numéricas: 20
# Variables categóricas: 5

# %%
pipeline_num = Pipeline([
    (
        "imputer",
        SimpleImputer(strategy="median")
    )
])

# %%
pipeline_categorico = Pipeline([
    (
        "imputer",
        SimpleImputer(strategy="most_frequent")
    ),
    (
        "encoder",
        OneHotEncoder(handle_unknown="ignore")
    )
])

# %%
preprocesador = ColumnTransformer(
    transformers=[
        (
            "num",
            pipeline_num,
            variables_numericas
        ),
        (
            "cat",
            pipeline_categorico,
            variables_categoricas
        )
    ]
)

# %%
X_transformado = preprocesador.fit_transform(X)

# %%
print(X_transformado.shape)
# Out:
# (1379562, 56)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (1103649, 25)
# X_test : (275913, 25)
# y_train: (1103649,)
# y_test : (275913,)

# %%
arbol_decision = DecisionTreeClassifier(
    max_depth=12,
    min_samples_split=20,
    min_samples_leaf=10,
    class_weight="balanced",
    random_state=42
)

# %%
modelo_inicial = Pipeline([
    ("preprocesamiento", preprocesador),
    ("modelo", arbol_decision)
])

# %%
modelo_inicial.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocesamiento',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['loan_amnt', 'annual_inc',
#                                                    'dti', 'fico_range_low',
#                                                    'fico_range_high',
#                                                    'delinq_2yrs',
#                                                    'inq_last_6mths', 'open_acc',
#                                                    'total_acc', 'pub_rec',
#                                                    'pub_rec_bankruptcies',
#                                                    'mort_acc', 'revol_bal',
#                                                    'revol_util',
#                                                    'collections_12_mths_e...
#                                                    'tot_cur_bal', 'num_sats']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['term', 'purpose',
#                                                    'verification_status',
#                                                    'emp_length',
#                                                    'home_ownership'])])),
#                 ('modelo',
#                  DecisionTreeClassifier(class_weight='balanced', max_depth=12,
#                                         min_samples_leaf=10,
#                                         min_samples_split=20,
#                                         random_state=42))])

# %%
y_pred = modelo_inicial.predict(X_test)

# %%
print(y_pred[:20])
# Out:
# [1 2 0 0 0 2 2 0 0 0 0 0 2 0 0 0 1 2 0 2]

# %%
comparacion = pd.DataFrame({
    "valor_real": y_test.iloc[:20].values,
    "prediccion": y_pred[:20]
})

comparacion
# Out:
#     valor_real  prediccion
# 0            2           1
# 1            2           2
# 2            0           0
# 3            0           0
# 4            0           0
# 5            0           2
# 6            0           2
# 7            0           0
# 8            0           0
# 9            0           0
# 10           1           0
# 11           0           0
# 12           0           2
# 13           0           0
# 14           0           0
# 15           0           0
# 16           0           1
# 17           0           2
# 18           0           0
# 19           0           2

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", round(accuracy, 4))
# Out:
# Accuracy: 0.5175

# %%
balanced_accuracy = balanced_accuracy_score(y_test, y_pred)

print("Balanced accuracy:", round(balanced_accuracy, 4))
# Out:
# Balanced accuracy: 0.4505

# %%
nombres_clases = [
    "Riesgo bajo",
    "Riesgo medio",
    "Riesgo alto"
]

print(
    classification_report(
        y_test,
        y_pred,
        target_names=nombres_clases,
        digits=4
    )
)
# Out:
#               precision    recall  f1-score   support
#
#  Riesgo bajo     0.8607    0.5457    0.6679    215351
# Riesgo medio     0.0428    0.3842    0.0770      6850
#  Riesgo alto     0.2910    0.4216    0.3443     53712
#
#     accuracy                         0.5175    275913
#    macro avg     0.3981    0.4505    0.3631    275913
# weighted avg     0.7295    0.5175    0.5902    275913

# %%
matriz = confusion_matrix(y_test, y_pred)

matriz
# Out:
# array([[117515,  44851,  52985],
#        [  2025,   2632,   2193],
#        [ 16998,  14071,  22643]])

# %%
visualizacion = ConfusionMatrixDisplay(
    confusion_matrix=matriz,
    display_labels=nombres_clases
)

visualizacion.plot(
    values_format="d",
    xticks_rotation=0
)

plt.title("Matriz de confusión del Árbol de Decisión")
plt.show()

# %%
importancias = modelo_inicial.named_steps["modelo"].feature_importances_

# %%
modelo = modelo_inicial.named_steps["modelo"]

# %%
importancias = modelo.feature_importances_

# %%
nombres_variables = modelo_inicial.named_steps[
    "preprocesamiento"
].get_feature_names_out()

# %%
tabla_importancias = pd.DataFrame({
    "Variable": nombres_variables,
    "Importancia": importancias
})

tabla_importancias = (
    tabla_importancias
    .sort_values(
        by="Importancia",
        ascending=False
    )
)

tabla_importancias.head(30)
# Out:
#                                     Variable  Importancia
# 20                      cat__term_ 36 months     0.177753
# 2                                   num__dti     0.109696
# 0                             num__loan_amnt     0.108909
# 18                          num__tot_cur_bal     0.083607
# 4                       num__fico_range_high     0.078929
# 11                             num__mort_acc     0.071849
# 1                            num__annual_inc     0.060227
# 8                             num__total_acc     0.058796
# 13                           num__revol_util     0.051443
# 12                            num__revol_bal     0.048351
# 36     cat__verification_status_Not Verified     0.023602
# 3                        num__fico_range_low     0.022834
# 6                        num__inq_last_6mths     0.017784
# 19                             num__num_sats     0.015220
# 38         cat__verification_status_Verified     0.010073
# 17                         num__tot_coll_amt     0.009666
# 7                              num__open_acc     0.008886
# 5                           num__delinq_2yrs     0.005237
# 9                               num__pub_rec     0.003761
# 24           cat__purpose_debt_consolidation     0.003394
# 37  cat__verification_status_Source Verified     0.002599
# 31                        cat__purpose_other     0.002548
# 40                 cat__emp_length_10+ years     0.002386
# 23                  cat__purpose_credit_card     0.002139
# 51              cat__home_ownership_MORTGAGE     0.001856
# 33               cat__purpose_small_business     0.001794
# 14           num__collections_12_mths_ex_med     0.001654
# 41                   cat__emp_length_2 years     0.001505
# 55                  cat__home_ownership_RENT     0.001503
# 54                   cat__home_ownership_OWN     0.001329

# %%
tabla_original = tabla_importancias.copy()

def obtener_variable_original(nombre):
   
    nombre = nombre.replace("num__", "").replace("cat__", "")

    
    if nombre.startswith("term_"):
        return "term"

    if nombre.startswith("purpose_"):
        return "purpose"

    if nombre.startswith("verification_status_"):
        return "verification_status"

    if nombre.startswith("emp_length_"):
        return "emp_length"

    if nombre.startswith("home_ownership_"):
        return "home_ownership"

   
    return nombre

tabla_original["Variable_original"] = tabla_original["Variable"].apply(
    obtener_variable_original
)

tabla_final = (
    tabla_original
    .groupby("Variable_original")["Importancia"]
    .sum()
    .sort_values(ascending=False)
    .reset_index()
)

tabla_final
# Out:
#              Variable_original  Importancia
# 0                         term     0.177753
# 1                          dti     0.109696
# 2                    loan_amnt     0.108909
# 3                  tot_cur_bal     0.083607
# 4              fico_range_high     0.078929
# 5                     mort_acc     0.071849
# 6                   annual_inc     0.060227
# 7                    total_acc     0.058796
# 8                   revol_util     0.051443
# 9                    revol_bal     0.048351
# 10         verification_status     0.036274
# 11              fico_range_low     0.022834
# 12              inq_last_6mths     0.017784
# 13                    num_sats     0.015220
# 14                     purpose     0.012044
# 15                  emp_length     0.010806
# 16                tot_coll_amt     0.009666
# 17                    open_acc     0.008886
# 18                 delinq_2yrs     0.005237
# 19              home_ownership     0.004688
# 20                     pub_rec     0.003761
# 21  collections_12_mths_ex_med     0.001654
# 22        pub_rec_bankruptcies     0.000862
# 23                   tax_liens     0.000550
# 24              acc_now_delinq     0.000173

# %%
variables_finales = [
    "loan_amnt",
    "term",
    "purpose",
    "annual_inc",
    "verification_status",
    "emp_length",
    "home_ownership",
    "dti",
    "fico_range_low",
    "inq_last_6mths",
    "total_acc",
    "mort_acc",
    "pub_rec",
    "delinq_2yrs",
    "pub_rec_bankruptcies"
]

# %%
X_final = df_modelo[variables_finales]

y_final = df_modelo["risk_level"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_final,
    y_final,
    test_size=0.20,
    random_state=42,
    stratify=y_final
)

# %%
variables_numericas = X_train.select_dtypes(
    include=["number"]
).columns.tolist()

variables_categoricas = X_train.select_dtypes(
    include=["object", "string"]
).columns.tolist()

print("Numéricas:", variables_numericas)
print("Categóricas:", variables_categoricas)
# Out:
# Numéricas: ['loan_amnt', 'annual_inc', 'dti', 'fico_range_low', 'inq_last_6mths', 'total_acc', 'mort_acc', 'pub_rec', 'delinq_2yrs', 'pub_rec_bankruptcies']
# Categóricas: ['term', 'purpose', 'verification_status', 'emp_length', 'home_ownership']

# %%
pipeline_numerico = Pipeline([
    ("imputer", SimpleImputer(strategy="median"))
])

pipeline_categorico = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

preprocesador = ColumnTransformer([
    ("num", pipeline_numerico, variables_numericas),
    ("cat", pipeline_categorico, variables_categoricas)
])

# %%
arbol_final = DecisionTreeClassifier(
    max_depth=12,
    min_samples_split=20,
    min_samples_leaf=10,
    class_weight="balanced",
    random_state=42
)

# %%
modelo_final = Pipeline([
    ("preprocesamiento", preprocesador),
    ("modelo", arbol_final)
])

# %%
modelo_final.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocesamiento',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['loan_amnt', 'annual_inc',
#                                                    'dti', 'fico_range_low',
#                                                    'inq_last_6mths',
#                                                    'total_acc', 'mort_acc',
#                                                    'pub_rec', 'delinq_2yrs',
#                                                    'pub_rec_bankruptcies']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['term', 'purpose',
#                                                    'verification_status',
#                                                    'emp_length',
#                                                    'home_ownership'])])),
#                 ('modelo',
#                  DecisionTreeClassifier(class_weight='balanced', max_depth=12,
#                                         min_samples_leaf=10,
#                                         min_samples_split=20,
#                                         random_state=42))])

# %%
y_pred = modelo_final.predict(X_test)

# %%
print("Accuracy:", round(accuracy_score(y_test, y_pred), 4))
print("Balanced Accuracy:", round(balanced_accuracy_score(y_test, y_pred), 4))
# Out:
# Accuracy: 0.5209
# Balanced Accuracy: 0.4492

# %%
print(
    classification_report(
        y_test,
        y_pred,
        target_names=[
            "Riesgo bajo",
            "Riesgo medio",
            "Riesgo alto"
        ],
        digits=4
    )
)
# Out:
#               precision    recall  f1-score   support
#
#  Riesgo bajo     0.8630    0.5402    0.6645    215351
# Riesgo medio     0.0428    0.3410    0.0761      6850
#  Riesgo alto     0.2892    0.4663    0.3570     53712
#
#     accuracy                         0.5209    275913
#    macro avg     0.3983    0.4492    0.3659    275913
# weighted avg     0.7309    0.5209    0.5900    275913
